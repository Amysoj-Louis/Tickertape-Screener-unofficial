# %%
import requests
import json
import pandas as pd

url = 'https://api.tickertape.in/screener/query'
payload = {
    "sortBy": "mrktCapf",
    # limit data within range
    "match": {"mrktCapf": {"g": 0, "l": 990301.9231}},
    "sortOrder": -1,
    # add various other parameters according to you need
    "project": ["subindustry", "mrktCapf", "lastPrice", "apef"],
    "offset": 0,
    "count": 500,  # number of Stocks
    "sids": []
}

headers = {
    'user-agent':
    'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Mobile Safari/537.36',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
}
r = requests.post(url=url, json=payload, headers=headers).json()
Ticker_ls, Name_ls, Last_Price_ls, Market_Cap_ls, Sector_ls = [], [], [], [], []
for result in r['data']['results']:
    name = result[u'stock'][u'info'][u'name']
    ticker = result[u'stock'][u'info'][u'ticker']
    sector = result[u'stock'][u'info'][u'sector']
    # this is of type str and not type float
    lastprice = "%.2f" % result[u'stock'][u'advancedRatios'][u'lastPrice']
    # this is of type str and not type float
    marketcap = "%.2f" % result[u'stock'][u'advancedRatios'][u'mrktCapf']
    Name_ls.append(name)
    Ticker_ls.append(ticker)
    Sector_ls.append(sector)
    Last_Price_ls.append(lastprice)
    Market_Cap_ls.append(marketcap)
df = pd.DataFrame([Name_ls, Ticker_ls, Sector_ls,
                  Market_Cap_ls, Last_Price_ls]).T
df.columns = ["Name", "Ticker", "Sector", "Market Cap", "Last Price"]

# Decoration
##########################################################
df = df.style.set_properties(**{'text-align': 'left'})
df = df.set_table_styles(
    [dict(selector='th', props=[('text-align', 'left')])])

##########################################################

display(df)
# Out:
# <style type="text/css">
# #T_238f3 th {
#   text-align: left;
# }
# #T_238f3_row0_col0, #T_238f3_row0_col1, #T_238f3_row0_col2, #T_238f3_row0_col3, #T_238f3_row0_col4, #T_238f3_row1_col0, #T_238f3_row1_col1, #T_238f3_row1_col2, #T_238f3_row1_col3, #T_238f3_row1_col4, #T_238f3_row2_col0, #T_238f3_row2_col1, #T_238f3_row2_col2, #T_238f3_row2_col3, #T_238f3_row2_col4, #T_238f3_row3_col0, #T_238f3_row3_col1, #T_238f3_row3_col2, #T_238f3_row3_col3, #T_238f3_row3_col4, #T_238f3_row4_col0, #T_238f3_row4_col1, #T_238f3_row4_col2, #T_238f3_row4_col3, #T_238f3_row4_col4, #T_238f3_row5_col0, #T_238f3_row5_col1, #T_238f3_row5_col2, #T_238f3_row5_col3, #T_238f3_row5_col4, #T_238f3_row6_col0, #T_238f3_row6_col1, #T_238f3_row6_col2, #T_238f3_row6_col3, #T_238f3_row6_col4, #T_238f3_row7_col0, #T_238f3_row7_col1, #T_238f3_row7_col2, #T_238f3_row7_col3, #T_238f3_row7_col4, #T_238f3_row8_col0, #T_238f3_row8_col1, #T_238f3_row8_col2, #T_238f3_row8_col3, #T_238f3_row8_col4, #T_238f3_row9_col0, #T_238f3_row9_col1, #T_238f3_row9_col2, #T_238f3_row9_col3, #T_238f3_row9_col4, #T_238f3_row10_col0, #T_238f3_row10_col1, #T_238f3_row10_col2, #T_238f3_row10_col3, #T_238f3_row10_col4, #T_238f3_row11_col0, #T_238f3_row11_col1, #T_238f3_row11_col2, #T_238f3_row11_col3, #T_238f3_row11_col4, #T_238f3_row12_col0, #T_238f3_row12_col1, #T_238f3_row12_col2, #T_238f3_row12_col3, #T_238f3_row12_col4, #T_238f3_row13_col0, #T_238f3_